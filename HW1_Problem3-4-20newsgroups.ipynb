# %%
# code source from http://scikit-learn.org/stable/datasets/twenty_newsgroups.html#
# code source from http://www.nltk.org/book/ch02.html
# code source from http://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.euclidean_distances.html

from sklearn.datasets import fetch_20newsgroups

import nltk
from nltk.corpus import stopwords
import string


# extracts the archive contents in the ~/scikit_learn_data/20news_home folder 
newsgroups_train = fetch_20newsgroups(subset='train')
newsgroups_test = fetch_20newsgroups(subset='test')

################# this part is for pre-processing the text file which isn't mandatory
# get rid of the stopwords and punctuation
nltk.download('stopwords')
stop_word =stopwords.words('english')
punctuation = string.punctuation
stopw_punctuation = list(stop_word) + list(punctuation)

from nltk.tokenize import word_tokenize

# to tokenize the word
for j in range(len(newsgroups_train.data)):
    newsgroups_train.data[j] = " ".join([w for w in word_tokenize(newsgroups_train.data[j]) if w not in stopw_punctuation])
   # print(newsgroups_train.data[])
for j in range(len(newsgroups_test.data)):
    newsgroups_test.data[j] = " ".join([w for w in word_tokenize(newsgroups_train.data[j]) if w not in stopw_punctuation])

#print(len(newsgroups_train.data))
#print(newsgroups_train.data[1])

##############

# from http://scikit-learn.org/stable/datasets/twenty_newsgroups.html
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
vectors_train = vectorizer.fit_transform(newsgroups_train.data)
# the test data set don't need to fit
vectors_test = vectorizer.transform(newsgroups_test.data)
print(vectors_train.shape)
print(vectors_test.shape)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/deshenghu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# (11314, 130088)
# (7532, 130088)

# %%
# code source from http://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.euclidean_distances.html
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.metrics.pairwise import cosine_similarity

similarity_ED = euclidean_distances(vectors_train, vectors_test)
similarity_COSINE = cosine_similarity(vectors_train, vectors_test)

print(similarity_ED.shape)
print(similarity_COSINE.shape)
# Out:
# (11314, 7532)
# (11314, 7532)

# %%
print(newsgroups_train.target)
print(newsgroups_train.target_names)
print(newsgroups_train.target[7])
# Out:
# [7 4 4 ..., 3 1 8]
# ['alt.atheism', 'comp.graphics', 'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware', 'comp.windows.x', 'misc.forsale', 'rec.autos', 'rec.motorcycles', 'rec.sport.baseball', 'rec.sport.hockey', 'sci.crypt', 'sci.electronics', 'sci.med', 'sci.space', 'soc.religion.christian', 'talk.politics.guns', 'talk.politics.mideast', 'talk.politics.misc', 'talk.religion.misc']
# 3

# %%
import numpy as np

# learn code from this source: https://docs.python.org/2/library/collections.html#collections.Counter
# A Counter is a dict subclass for counting hashable objects. 
from collections import Counter

Y_train = newsgroups_train.target

def Find_KNN(idx, k, similarity_matrix):
    
    
    index_KNN = np.argsort(np.array(similarity_ED[idx, :]))[:k]
    print("The index of the K nearest neighbours are:",index_KNN)
    
   
    label_final , count = Counter(Y_train[index_KNN]).most_common()[0]
    
    print("The labels for the index before are:",Y_train[index_KNN])
    
    #print("The labels for the index before are:",Y_train[index_KNN].target_names)
    
    #convert the target names into array
    convert_array = np.array(newsgroups_train.target_names)
    #convert the lables into array 
    label_array = np.array(Y_train[index_KNN])
    
    # here convert_array[label_array] is the targetname corresponding to that label
    print("The KNN categories are :", convert_array[label_array])
    
    
   # print(list(Y_train[index_KNN])
   # print(np.array(newsgroups))
    print("The final label is:", label_final)
    
 
    
    
    return label_final

Find_KNN(10, 5, similarity_ED )
# Out:
# The index of the K nearest neighbours are: [  10 3543 6593 1143 4211]
# The labels for the index before are: [8 8 8 6 8]
# The KNN categories are : ['rec.motorcycles' 'rec.motorcycles' 'rec.motorcycles' 'misc.forsale'
#  'rec.motorcycles']
# The final label is: 8
# 8

# %%
seed_index = np.random.randint(7500, size=1200)

print(seed_index)

count_accuracy = 0

Y_train = newsgroups_test.target

for i in seed_index:
    train_label = Find_KNN(i, 5, similarity_ED)
    real_label = Y_train[i]
    if train_label== real_label:
        count_accuracy += 1
        
        
        
        
       
    #print(train_label, real_label)

Final_accuracy = float(count_accuracy)/float(len(seed_index))
print("Final Accuracy is:", Final_accuracy ) 
    
    #if train_label
# Out:
# [ 276 2051 4015 ...,  201 7198 5147]
# The index of the K nearest neighbours are: [ 276 6573 6562 2203  204]
# The labels for the index before are: [ 5 15 19 18 15]
# The KNN categories are : ['comp.windows.x' 'soc.religion.christian' 'talk.religion.misc'
#  'talk.politics.misc' 'soc.religion.christian']
# The final label is: 15
# The index of the K nearest neighbours are: [2051  138 4769 6494 6453]
# The labels for the index before are: [12  3  3 11  1]
# The KNN categories are : ['sci.electronics' 'comp.sys.ibm.pc.hardware' 'comp.sys.ibm.pc.hardware'
#  'sci.crypt' 'comp.graphics']
# The final label is: 3
# The index of the K nearest neighbours are: [4015 2201 5658 4839 1966]
# The labels for the index before are: [ 0 18 17  8 14]
# The KNN categories are : ['alt.atheism' 'talk.politics.misc' 'talk.politics.mideast'
#  'rec.motorcycles' 'sci.space']
# The final label is: 0
# The index of the K nearest neighbours are: [ 475 5611 2723 4135 4144]
# The labels for the index before are: [13 12 13  4  6]
# The KNN categories are : ['sci.med' 'sci.electronics' 'sci.med' 'comp.sys.mac.hardware'
#  'misc.forsale']
# The final label is: 13
# The index of the K nearest neighbours are: [2836  367  171 3004 7247]
# The labels for the index before are: [ 8  4  7 13 12]
# The KNN categories are : ['rec.motorcycles' 'comp.sys.mac.hardware' 'rec.autos' 'sci.med'
#  'sci.electronics']
# The final label is: 8
# The index of the K nearest neighbours are: [4079 5559 3391  721 2727]
# The labels for the index before are: [11  6  0 12 11]
# The KNN categories are : ['sci.crypt' 'misc.forsale' 'alt.atheism' 'sci.electronics' 'sci.crypt']
# The final label is: 11
# The index of the K nearest neighbours are: [1357 3990 5062 6572 6279]
# The labels for the index before are: [17  2  9  7 16]
# The KNN categories are : ['talk.politics.mideast' 'comp.os.ms-windows.misc' 'rec.sport.baseball'
#  'rec.autos' 'talk.politics.guns']
# The final label is: 17
# The index of the K nearest neighbours are: [6672 1015 3086  291 2480]
# The labels for the index before are: [ 9 10 13  3 13]
# The KNN categories are : ['rec.sport.baseball' 'rec.sport.hockey' 'sci.med'
#  'comp.sys.ibm.pc.hardware' 'sci.med']
# The final label is: 13
# The index of the K nearest neighbours are: [4378 2214  612 1867 6162]
# The labels for the index before are: [ 3 17 15  4 15]
# The KNN categories are : ['comp.sys.ibm.pc.hardware' 'talk.politics.mideast'
#  'soc.religion.christian' 'comp.sys.mac.hardware' 'soc.religion.christian']
# The final label is: 15
# The index of the K nearest neighbours are: [2336 5816 2775 5293 3533]
# The labels for the index before are: [ 8  5 19  2 13]
# The KNN categories are : ['rec.motorcycles' 'comp.windows.x' 'talk.religion.misc'
#  'comp.os.ms-windows.misc' 'sci.med']
# The final label is: 8
# The index of the K nearest neighbours are: [6374  564  463 1001 5985]
# The labels for the index before are: [10  9  5 16  9]
# The KNN categories are : ['rec.sport.hockey' 'rec.sport.baseball' 'comp.windows.x'
#  'talk.politics.guns' 'rec.sport.baseball']
# The final label is: 9
# The index of the K nearest neighbours are: [2696    9 7492 6029 6172]
# The labels for the index before are: [ 1  1  0 12  7]
# The KNN categories are : ['comp.graphics' 'comp.graphics' 'alt.atheism' 'sci.electronics'
#  'rec.autos']
# The final label is: 1
# The index of the K nearest neighbours are: [5210 7068 6742 6097  696]
# The labels for the index before are: [19  1 14  5  9]
# The KNN categories are : ['talk.religion.misc' 'comp.graphics' 'sci.space' 'comp.windows.x'
#  'rec.sport.baseball']
# The final label is: 19
# The index of the K nearest neighbours are: [ 406 1920   32 6235 7308]
# The labels for the index before are: [12 17  4  4  6]
# The KNN categories are : ['sci.electronics' 'talk.politics.mideast' 'comp.sys.mac.hardware'
#  'comp.sys.mac.hardware' 'misc.forsale']
# The final label is: 4
# The index of the K nearest neighbours are: [4049  847 5429 2800 4425]
# The labels for the index before are: [ 7 17  0 19  7]
# The KNN categories are : ['rec.autos' 'talk.politics.mideast' 'alt.atheism' 'talk.religion.misc'
#  'rec.autos']
# The final label is: 7
# The index of the K nearest neighbours are: [5633  669 2137 4361 7392]
# The labels for the index before are: [ 8 11 13 14  2]
# The KNN categories are : ['rec.motorcycles' 'sci.crypt' 'sci.med' 'sci.space'
#  'comp.os.ms-windows.misc']
# The final label is: 8
# The index of the K nearest neighbours are: [6245 2317 6144 6260 2171]
# The labels for the index before are: [ 4  4 18  0 16]
# The KNN categories are : ['comp.sys.mac.hardware' 'comp.sys.mac.hardware' 'talk.politics.misc'
#  'alt.atheism' 'talk.politics.guns']
# The final label is: 4
# The index of the K nearest neighbours are: [2585 3316  642 1942 1941]
# The labels for the index before are: [ 4  9  9 14  2]
# The KNN categories are : ['comp.sys.mac.hardware' 'rec.sport.baseball' 'rec.sport.baseball'
#  'sci.space' 'comp.os.ms-windows.misc']
# The final label is: 9
# The index of the K nearest neighbours are: [1127 3040  344 3233 2765]
# The labels for the index before are: [13 15 13  8  1]
# The KNN categories are : ['sci.med' 'soc.religion.christian' 'sci.med' 'rec.motorcycles'
#  'comp.graphics']
# The final label is: 13
# The index of the K nearest neighbours are: [4425 2800 5729 1830  545]
# The labels for the index before are: [ 7 19 13  9  3]
# The KNN categories are : ['rec.autos' 'talk.religion.misc' 'sci.med' 'rec.sport.baseball'
#  'comp.sys.ibm.pc.hardware']
# The final label is: 7
# The index of the K nearest neighbours are: [2423 3098 5475 2577 1730]
# The labels for the index before are: [ 3  5  7  8 16]
# The KNN categories are : ['comp.sys.ibm.pc.hardware' 'comp.windows.x' 'rec.autos' 'rec.motorcycles'
#  'talk.politics.guns']
# The final label is: 3
# The index of the K nearest neighbours are: [1363 2697  960 2324 4540]
# The labels for the index before are: [ 3 11  9 13  5]
# The KNN categories are : ['comp.sys.ibm.pc.hardware' 'sci.crypt' 'rec.sport.baseball' 'sci.med'
#  'comp.windows.x']
# The final label is: 3
# The index of the K nearest neighbours are: [3098 1730 5430 3162 7221]
# The labels for the index before are: [ 5 16  3  0  8]
# The KNN categories are : ['comp.windows.x' 'talk.politics.guns' 'comp.sys.ibm.pc.hardware'
#  'alt.atheism' 'rec.motorcycles']
# The final label is: 5
# The index of the K nearest neighbours are: [1584 6759 4352  769  372]
# The labels for the index before are: [0 3 9 8 4]
# The KNN categories are : ['alt.atheism' 'comp.sys.ibm.pc.hardware' 'rec.sport.baseball'
#  'rec.motorcycles' 'comp.sys.mac.hardware']
# The final label is: 0
# The index of the K nearest neighbours are: [1971 4256  724  923 6147]
# The labels for the index before are: [ 3 15  9 18 15]
# The KNN categories are : ['comp.sys.ibm.pc.hardware' 'soc.religion.christian' 'rec.sport.baseball'
#  'talk.politics.misc' 'soc.religion.christian']
# The final label is: 15
# The index of the K nearest neighbours are: [3810 6076 4428 3262 2706]
# The labels for the index before are: [17  8  1  0 14]
# The KNN categories are : ['talk.politics.mideast' 'rec.motorcycles' 'comp.graphics' 'alt.atheism'
#  'sci.space']
# The final label is: 17
# The index of the K nearest neighbours are: [1014 1248 5589 3786 2671]
# The labels for the index before are: [ 9  3 14 10 18]
# The KNN categories are : ['rec.sport.baseball' 'comp.sys.ibm.pc.hardware' 'sci.space'
#  'rec.sport.hockey' 'talk.politics.misc']
# The final label is: 9
# The index of the K nearest neighbours are: [5044 7184 5596 3473 6939]
# The labels for the index before are: [12 11  5 16  2]
# The KNN categories are : ['sci.electronics' 'sci.crypt' 'comp.windows.x' 'talk.politics.guns'
#  'comp.os.ms-windows.misc']
# The final label is: 12
# The index of the K nearest neighbours are: [4786 1598 3350 1266 5954]
# The labels for the index before are: [10  9  9  4 17]
# The KNN categories are : ['rec.sport.hockey' 'rec.sport.baseball' 'rec.sport.baseball'
#  'comp.sys.mac.hardware' 'talk.politics.mideast']
# The final label is: 9
# The index of the K nearest neighbours are: [5606 4158 1204 3679 3922]
# The labels for the index before are: [18 18  1 17  5]
# The KNN categories are : ['talk.politics.misc' 'talk.politics.misc' 'comp.graphics'
#  'talk.politics.mideast' 'comp.windows.x']
# The final label is: 18
# The index of the K nearest neighbours are: [5522 2119 2916 3149 5185]
# The labels for the index before are: [18  2  0 15  8]
# The KNN categories are : ['talk.politics.misc' 'comp.os.ms-windows.misc' 'alt.atheism'
#  'soc.religion.christian' 'rec.motorcycles']
# The final label is: 18
# The index of the K nearest neighbours are: [7418 6282    7 5489 4370]
# The labels for the index before are: [14 15 15  4  2]
# The KNN categories are : ['sci.space' 'soc.religion.christian' 'soc.religion.christian'
#  'comp.sys.mac.hardware' 'comp.os.ms-windows.misc']
# The final label is: 15
# The index of the K nearest neighbours are: [1400  703 4988 2835 2345]
# The labels for the index before are: [ 4  5  8 13  1]
# The KNN categories are : ['comp.sys.mac.hardware' 'comp.windows.x' 'rec.motorcycles' 'sci.med'
#  'comp.graphics']
# The final label is: 4
# The index of the K nearest neighbours are: [2578 6987 4166 6719 6151]
# The labels for the index before are: [ 3  2  3 12 11]
# The KNN categories are : ['comp.sys.ibm.pc.hardware' 'comp.os.ms-windows.misc'
#  'comp.sys.ibm.pc.hardware' 'sci.electronics' 'sci.crypt']
# The final label is: 3
# The index of the K nearest neighbours are: [2390 3578  460 3853 4884]
# The labels for the index before are: [12 11 15  4 15]
# The KNN categories are : ['sci.electronics' 'sci.crypt' 'soc.religion.christian'
#  'comp.sys.mac.hardware' 'soc.religion.christian']
# The final label is: 15
# The index of the K nearest neighbours are: [5832 6147 1931 6480 6335]
# The labels for the index before are: [15 15 19 17  6]
# The KNN categories are : ['soc.religion.christian' 'soc.religion.christian' 'talk.religion.misc'
#  'talk.politics.mideast' 'misc.forsale']
# The final label is: 15
# The index of the K nearest neighbours are: [ 303 6066 2013  707 5709]
# The labels for the index before are: [ 6 13 12 16 18]
# The KNN categories are : ['misc.forsale' 'sci.med' 'sci.electronics' 'talk.politics.guns'
#  'talk.politics.misc']
# The final label is: 6
# The index of the K nearest neighbours are: [5866 1271 3469 4310 7310]
# The labels for the index before are: [9 5 3 9 7]
# The KNN categories are : ['rec.sport.baseball' 'comp.windows.x' 'comp.sys.ibm.pc.hardware'
#  'rec.sport.baseball' 'rec.autos']
# The final label is: 9
# The index of the K nearest neighbours are: [3903 3222 6607  205 6824]
# The labels for the index before are: [16  8 19 12 12]
# The KNN categories are : ['talk.politics.guns' 'rec.motorcycles' 'talk.religion.misc'
#  'sci.electronics' 'sci.electronics']
# The final label is: 12
# The index of the K nearest neighbours are: [5414 7083 2140 7389 2114]
# The labels for the index before are: [14 13 17  0  8]
# The KNN categories are : ['sci.space' 'sci.med' 'talk.politics.mideast' 'alt.atheism'
#  'rec.motorcycles']
# The final label is: 14
# The index of the K nearest neighbours are: [6287 2439  628 4321 2722]
# The labels for the index before are: [ 7  5  1 13 15]
# The KNN categories are : ['rec.autos' 'comp.windows.x' 'comp.graphics' 'sci.med'
#  'soc.religion.christian']
# The final label is: 7
# The index of the K nearest neighbours are: [6585 4225 6001 1101 1232]
# The labels for the index before are: [ 3  7  7 12  8]
# The KNN categories are : ['comp.sys.ibm.pc.hardware' 'rec.autos' 'rec.autos' 'sci.electronics'
#  'rec.motorcycles']
# The final label is: 7
# The index of the K nearest neighbours are: [3406 5451 3820 1702 4234]
# The labels for the index before are: [18 13  9 15 13]
# The KNN categories are : ['talk.politics.misc' 'sci.med' 'rec.sport.baseball'
#  'soc.religion.christian' 'sci.med']
# The final label is: 13
# The index of the K nearest neighbours are: [3787  315 2046 5699  872]
# The labels for the index before are: [ 5  4  0  2 15]
# The KNN categories are : ['comp.windows.x' 'comp.sys.mac.hardware' 'alt.atheism'
#  'comp.os.ms-windows.misc' 'soc.religion.christian']
# The final label is: 5
# The index of the K nearest neighbours are: [1983 2757 2140 1670 5015]
# The labels for the index before are: [10 16 17  2 15]
# The KNN categories are : ['rec.sport.hockey' 'talk.politics.guns' 'talk.politics.mideast'
#  'comp.os.ms-windows.misc' 'soc.religion.christian']
# The final label is: 10
# The index of the K nearest neighbours are: [4992 2937 4098 1774 7193]
# The labels for the index before are: [14 17 14  3  5]
# The KNN categories are : ['sci.space' 'talk.politics.mideast' 'sci.space' 'comp.sys.ibm.pc.hardware'
#  'comp.windows.x']
# The final label is: 14
# The index of the K nearest neighbours are: [ 950  212 5657 1778 2779]
# The labels for the index before are: [ 0 14 17 16 13]
# The KNN categories are : ['alt.atheism' 'sci.space' 'talk.politics.mideast' 'talk.politics.guns'
#  'sci.med']
# The final label is: 0
# The index of the K nearest neighbours are: [2832 2963 6027 1338 7213]
# The labels for the index before are: [ 9 10  5  0 14]
# The KNN categories are : ['rec.sport.baseball' 'rec.sport.hockey' 'comp.windows.x' 'alt.atheism'
#  'sci.space']
# The final label is: 9
# The index of the K nearest neighbours are: [2265  814 6695 2329 2276]
# The labels for the index before are: [ 8 12  4  6 17]
# The KNN categories are : ['rec.motorcycles' 'sci.electronics' 'comp.sys.mac.hardware' 'misc.forsale'
#  'talk.politics.mideast']
# The final label is: 8
# The index of the K nearest neighbours are: [1198 1549 6809 2001  681]
# The labels for the index before are: [14  0  2 13 14]
# The KNN categories are : ['sci.space' 'alt.atheism' 'comp.os.ms-windows.misc' 'sci.med' 'sci.space']
# The final label is: 14
# The index of the K nearest neighbours are: [6597 6746 6500  982 6675]
# The labels for the index before are: [10 10  8  0 17]
# The KNN categories are : ['rec.sport.hockey' 'rec.sport.hockey' 'rec.motorcycles' 'alt.atheism'
#  'talk.politics.mideast']
# The final label is: 10
# The index of the K nearest neighbours are: [3900 1974 5183 6730 5664]
# The labels for the index before are: [15  3  0 14 13]
# The KNN categories are : ['soc.religion.christian' 'comp.sys.ibm.pc.hardware' 'alt.atheism'
#  'sci.space' 'sci.med']
# The final label is: 15
# The index of the K nearest neighbours are: [5472 4695 7434 2409 1230]
# The labels for the index before are: [ 5  8  8  7 13]
# The KNN categories are : ['comp.windows.x' 'rec.motorcycles' 'rec.motorcycles' 'rec.autos' 'sci.med']
# The final label is: 8
# The index of the K nearest neighbours are: [6240 1956 3872 7036 1914]
# The labels for the index before are: [ 4 11 18 14  8]
# The KNN categories are : ['comp.sys.mac.hardware' 'sci.crypt' 'talk.politics.misc' 'sci.space'
#  'rec.motorcycles']
# The final label is: 4
# The index of the K nearest neighbours are: [6852 3700 6359 3750 2269]
# The labels for the index before are: [2 9 8 8 6]
# The KNN categories are : ['comp.os.ms-windows.misc' 'rec.sport.baseball' 'rec.motorcycles'
#  'rec.motorcycles' 'misc.forsale']
# The final label is: 8
# The index of the K nearest neighbours are: [ 195 2872 3468 4936  328]
# The labels for the index before are: [15 13  0  9  0]
# The KNN categories are : ['soc.religion.christian' 'sci.med' 'alt.atheism' 'rec.sport.baseball'
#  'alt.atheism']
# The final label is: 0
# The index of the K nearest neighbours are: [5915 2890 5305 5665 6640]
# The labels for the index before are: [ 6 16 16 18  4]
# The KNN categories are : ['misc.forsale' 'talk.politics.guns' 'talk.politics.guns'
#  'talk.politics.misc' 'comp.sys.mac.hardware']
# The final label is: 16
# The index of the K nearest neighbours are: [5218  165 2870 6387 1593]
# The labels for the index before are: [13  8 13 14  1]
# The KNN categories are : ['sci.med' 'rec.motorcycles' 'sci.med' 'sci.space' 'comp.graphics']
# The final label is: 13
# The index of the K nearest neighbours are: [2943 4782 5933 3264 5154]
# The labels for the index before are: [18  8  2  9  7]
# The KNN categories are : ['talk.politics.misc' 'rec.motorcycles' 'comp.os.ms-windows.misc'
#  'rec.sport.baseball' 'rec.autos']
# The final label is: 18
# The index of the K nearest neighbours are: [5215  510 1402 7143 5565]
# The labels for the index before are: [12 14  7  8 16]
# The KNN categories are : ['sci.electronics' 'sci.space' 'rec.autos' 'rec.motorcycles'
#  'talk.politics.guns']
# The final label is: 12
# The index of the K nearest neighbours are: [3548 4290 6549 2987 3771]
# The labels for the index before are: [12 13 12  9 18]
# The KNN categories are : ['sci.electronics' 'sci.med' 'sci.electronics' 'rec.sport.baseball'
#  'talk.politics.misc']
# The final label is: 12
# The index of the K nearest neighbours are: [5957 6034 1192 2065 3649]
# The labels for the index before are: [13 16  1 14  0]
# The KNN categories are : ['sci.med' 'talk.politics.guns' 'comp.graphics' 'sci.space' 'alt.atheism']
# The final label is: 13
# The index of the K nearest neighbours are: [6194 7208 1104  504  663]
# The labels for the index before are: [ 3 15  5 19  5]
# The KNN categories are : ['comp.sys.ibm.pc.hardware' 'soc.religion.christian' 'comp.windows.x'
#  'talk.religion.misc' 'comp.windows.x']
# The final label is: 5
# The index of the K nearest neighbours are: [3592  577 7125 2970 6955]
# The labels for the index before are: [15 14  8 17 16]
# The KNN categories are : ['soc.religion.christian' 'sci.space' 'rec.motorcycles'
#  'talk.politics.mideast' 'talk.politics.guns']
# The final label is: 15
# The index of the K nearest neighbours are: [1085 7117 3666 5754 3275]
# The labels for the index before are: [ 8 17  4  9 18]
# The KNN categories are : ['rec.motorcycles' 'talk.politics.mideast' 'comp.sys.mac.hardware'
#  'rec.sport.baseball' 'talk.politics.misc']
# The final label is: 8
# The index of the K nearest neighbours are: [4597 3355 6054 2752 4888]
# The labels for the index before are: [ 5 16 12 14 16]
# The KNN categories are : ['comp.windows.x' 'talk.politics.guns' 'sci.electronics' 'sci.space'
#  'talk.politics.guns']
# The final label is: 16
# The index of the K nearest neighbours are: [6296 1765 2645 1316   40]
# The labels for the index before are: [ 9 12 15 14 17]
# The KNN categories are : ['rec.sport.baseball' 'sci.electronics' 'soc.religion.christian'
#  'sci.space' 'talk.politics.mideast']
# The final label is: 9
# The index of the K nearest neighbours are: [2093 6952 5255 3426 5549]
# The labels for the index before are: [ 6  0 12  3  5]
# The KNN categories are : ['misc.forsale' 'alt.atheism' 'sci.electronics' 'comp.sys.ibm.pc.hardware'
#  'comp.windows.x']
# The final label is: 6
# The index of the K nearest neighbours are: [6109 7436 5312 2414 2298]
# The labels for the index before are: [10  9  9 10  8]
# The KNN categories are : ['rec.sport.hockey' 'rec.sport.baseball' 'rec.sport.baseball'
#  'rec.sport.hockey' 'rec.motorcycles']
# The final label is: 10
# The index of the K nearest neighbours are: [1784 4022 3007 5854 2276]
# The labels for the index before are: [14 17  6  6 17]
# The KNN categories are : ['sci.space' 'talk.politics.mideast' 'misc.forsale' 'misc.forsale'
#  'talk.politics.mideast']
# The final label is: 17
# The index of the K nearest neighbours are: [6815  680 1206 2047 6805]
# The labels for the index before are: [ 4  8 15  5  0]
# The KNN categories are : ['comp.sys.mac.hardware' 'rec.motorcycles' 'soc.religion.christian'
#  'comp.windows.x' 'alt.atheism']
# The final label is: 4
# The index of the K nearest neighbours are: [3946  757 4387 1126 3311]
# The labels for the index before are: [ 0  7 10 13 11]
# The KNN categories are : ['alt.atheism' 'rec.autos' 'rec.sport.hockey' 'sci.med' 'sci.crypt']
# The final label is: 0
# The index of the K nearest neighbours are: [ 998 2963 7213 1338 4946]
# The labels for the index before are: [18 10 14  0 18]
# The KNN categories are : ['talk.politics.misc' 'rec.sport.hockey' 'sci.space' 'alt.atheism'
#  'talk.politics.misc']
# The final label is: 18
# The index of the K nearest neighbours are: [6814 3137 5459  750  566]
# The labels for the index before are: [ 8 11  3 10  1]
# The KNN categories are : ['rec.motorcycles' 'sci.crypt' 'comp.sys.ibm.pc.hardware'
#  'rec.sport.hockey' 'comp.graphics']
# The final label is: 8
# The index of the K nearest neighbours are: [2302 1268 2532 5944 4650]
# The labels for the index before are: [ 2 19  4  0 14]
# The KNN categories are : ['comp.os.ms-windows.misc' 'talk.religion.misc' 'comp.sys.mac.hardware'
#  'alt.atheism' 'sci.space']
# The final label is: 2
# The index of the K nearest neighbours are: [1813 6875 5450 5426 7283]
# The labels for the index before are: [18  1 18 14 17]
# The KNN categories are : ['talk.politics.misc' 'comp.graphics' 'talk.politics.misc' 'sci.space'
#  'talk.politics.mideast']
# The final label is: 18
# The index of the K nearest neighbours are: [ 722 1807 6038 4668 6654]
# The labels for the index before are: [18  3 15 19 10]
# The KNN categories are : ['talk.politics.misc' 'comp.sys.ibm.pc.hardware' 'soc.religion.christian'
#  'talk.religion.misc' 'rec.sport.hockey']
# The final label is: 18
# The index of the K nearest neighbours are: [1731  520 3689 1044 6734]
# The labels for the index before are: [ 4 10 15 11 17]
# The KNN categories are : ['comp.sys.mac.hardware' 'rec.sport.hockey' 'soc.religion.christian'
#  'sci.crypt' 'talk.politics.mideast']
# The final label is: 4
# The index of the K nearest neighbours are: [7397 7435 4659 4959 6940]
# The labels for the index before are: [18  9 11  1 11]
# The KNN categories are : ['talk.politics.misc' 'rec.sport.baseball' 'sci.crypt' 'comp.graphics'
#  'sci.crypt']
# The final label is: 11
# The index of the K nearest neighbours are: [2317 6245 6144 2171 4113]
# The labels for the index before are: [ 4  4 18 16  6]
# The KNN categories are : ['comp.sys.mac.hardware' 'comp.sys.mac.hardware' 'talk.politics.misc'
#  'talk.politics.guns' 'misc.forsale']
# The final label is: 4
# The index of the K nearest neighbours are: [5087 3396 2360 7213 1338]
# The labels for the index before are: [17  4  3 14  0]
# The KNN categories are : ['talk.politics.mideast' 'comp.sys.mac.hardware' 'comp.sys.ibm.pc.hardware'
#  'sci.space' 'alt.atheism']
# The final label is: 17
# The index of the K nearest neighbours are: [4235 4665 2926 5311 5765]
# The labels for the index before are: [17  8 10 13 15]
# The KNN categories are : ['talk.politics.mideast' 'rec.motorcycles' 'rec.sport.hockey' 'sci.med'
#  'soc.religion.christian']
# The final label is: 17
# The index of the K nearest neighbours are: [2759 3951 4227 2968   26]
# The labels for the index before are: [ 5 13 13 14 11]
# The KNN categories are : ['comp.windows.x' 'sci.med' 'sci.med' 'sci.space' 'sci.crypt']
# The final label is: 13
# The index of the K nearest neighbours are: [ 400  694 3904 3621 3270]
# The labels for the index before are: [ 0  0 19 13  7]
# The KNN categories are : ['alt.atheism' 'alt.atheism' 'talk.religion.misc' 'sci.med' 'rec.autos']
# The final label is: 0
# The index of the K nearest neighbours are: [5964 1115 6683 5277 1436]
# The labels for the index before are: [ 5 13 11  8 15]
# The KNN categories are : ['comp.windows.x' 'sci.med' 'sci.crypt' 'rec.motorcycles'
#  'soc.religion.christian']
# The final label is: 5
# The index of the K nearest neighbours are: [4408  297 7166 2901  922]
# The labels for the index before are: [ 2  4 11  0  9]
# The KNN categories are : ['comp.os.ms-windows.misc' 'comp.sys.mac.hardware' 'sci.crypt'
#  'alt.atheism' 'rec.sport.baseball']
# The final label is: 2
# The index of the K nearest neighbours are: [6717 6142 6816 5761 7031]
# The labels for the index before are: [ 8  8 17 14  9]
# The KNN categories are : ['rec.motorcycles' 'rec.motorcycles' 'talk.politics.mideast' 'sci.space'
#  'rec.sport.baseball']
# The final label is: 8
# The index of the K nearest neighbours are: [3139 2745 2694 7178 5882]
# The labels for the index before are: [18 10  6  7 12]
# The KNN categories are : ['talk.politics.misc' 'rec.sport.hockey' 'misc.forsale' 'rec.autos'
#  'sci.electronics']
# The final label is: 18
# The index of the K nearest neighbours are: [5537 6022 2888 2274  566]
# The labels for the index before are: [ 4 17 13 19  1]
# The KNN categories are : ['comp.sys.mac.hardware' 'talk.politics.mideast' 'sci.med'
#  'talk.religion.misc' 'comp.graphics']
# The final label is: 4
# The index of the K nearest neighbours are: [4568 3071 6782 1699 5791]
# The labels for the index before are: [ 9  8  6 17  4]
# The KNN categories are : ['rec.sport.baseball' 'rec.motorcycles' 'misc.forsale'
#  'talk.politics.mideast' 'comp.sys.mac.hardware']
# The final label is: 9
# The index of the K nearest neighbours are: [5388 5604 1720 6504 1958]
# The labels for the index before are: [12 19  0  6  6]
# The KNN categories are : ['sci.electronics' 'talk.religion.misc' 'alt.atheism' 'misc.forsale'
#  'misc.forsale']
# The final label is: 6
# The index of the K nearest neighbours are: [5518 6114 4445  854 2953]
# The labels for the index before are: [ 1  2 10 10 14]
# The KNN categories are : ['comp.graphics' 'comp.os.ms-windows.misc' 'rec.sport.hockey'
#  'rec.sport.hockey' 'sci.space']
# The final label is: 10
# The index of the K nearest neighbours are: [ 216 1474 2522 3012 3420]
# The labels for the index before are: [ 1  6  8  1 11]
# The KNN categories are : ['comp.graphics' 'misc.forsale' 'rec.motorcycles' 'comp.graphics'
#  'sci.crypt']
# The final label is: 1
# The index of the K nearest neighbours are: [4566 2035 2816 4314  149]
# The labels for the index before are: [ 5  5  1  1 13]
# The KNN categories are : ['comp.windows.x' 'comp.windows.x' 'comp.graphics' 'comp.graphics'
#  'sci.med']
# The final label is: 5
# The index of the K nearest neighbours are: [1546 1709 3961  745 1677]
# The labels for the index before are: [12  5 17  7 12]
# The KNN categories are : ['sci.electronics' 'comp.windows.x' 'talk.politics.mideast' 'rec.autos'
#  'sci.electronics']
# The final label is: 12
# The index of the K nearest neighbours are: [4459 4554 3910 1618 4841]
# The labels for the index before are: [ 4  9 18 11 10]
# The KNN categories are : ['comp.sys.mac.hardware' 'rec.sport.baseball' 'talk.politics.misc'
#  'sci.crypt' 'rec.sport.hockey']
# The final label is: 4
# The index of the K nearest neighbours are: [7003 5634 4629 6977  516]
# The labels for the index before are: [14 16 10  7 12]
# The KNN categories are : ['sci.space' 'talk.politics.guns' 'rec.sport.hockey' 'rec.autos'
#  'sci.electronics']
# The final label is: 14
# The index of the K nearest neighbours are: [2369 5688 4018 2489 1968]
# The labels for the index before are: [5 5 3 1 9]
# The KNN categories are : ['comp.windows.x' 'comp.windows.x' 'comp.sys.ibm.pc.hardware'
#  'comp.graphics' 'rec.sport.baseball']
# The final label is: 5
# The index of the K nearest neighbours are: [6561 2500 2173 5917 4983]
# The labels for the index before are: [12 15 13 13  5]
# The KNN categories are : ['sci.electronics' 'soc.religion.christian' 'sci.med' 'sci.med'
#  'comp.windows.x']
# The final label is: 13
# The index of the K nearest neighbours are: [1910 2973  321 6664 3129]
# The labels for the index before are: [19 17 13 14 16]
# The KNN categories are : ['talk.religion.misc' 'talk.politics.mideast' 'sci.med' 'sci.space'
#  'talk.politics.guns']
# The final label is: 19
# The index of the K nearest neighbours are: [7089  537 7148  202 1804]
# The labels for the index before are: [ 9  9  3  4 16]
# The KNN categories are : ['rec.sport.baseball' 'rec.sport.baseball' 'comp.sys.ibm.pc.hardware'
#  'comp.sys.mac.hardware' 'talk.politics.guns']
# The final label is: 9
# The index of the K nearest neighbours are: [5147 6959 6680 7052 3981]
# The labels for the index before are: [12 15 10  4  1]
# The KNN categories are : ['sci.electronics' 'soc.religion.christian' 'rec.sport.hockey'
#  'comp.sys.mac.hardware' 'comp.graphics']
# The final label is: 12
# The index of the K nearest neighbours are: [4040 3229 5326 6619  449]
# The labels for the index before are: [15 17 15  8  7]
# The KNN categories are : ['soc.religion.christian' 'talk.politics.mideast' 'soc.religion.christian'
#  'rec.motorcycles' 'rec.autos']
# The final label is: 15
# The index of the K nearest neighbours are: [7277 5273 7222 3152 5352]
# The labels for the index before are: [6 8 1 8 6]
# The KNN categories are : ['misc.forsale' 'rec.motorcycles' 'comp.graphics' 'rec.motorcycles'
#  'misc.forsale']
# The final label is: 6
# The index of the K nearest neighbours are: [6459 2200   39 1384 5771]
# The labels for the index before are: [13  5  1 13  2]
# The KNN categories are : ['sci.med' 'comp.windows.x' 'comp.graphics' 'sci.med'
#  'comp.os.ms-windows.misc']
# The final label is: 13
# The index of the K nearest neighbours are: [ 395 7176 2286 3023 4010]
# The labels for the index before are: [ 8  1  5  3 13]
# The KNN categories are : ['rec.motorcycles' 'comp.graphics' 'comp.windows.x'
#  'comp.sys.ibm.pc.hardware' 'sci.med']
# The final label is: 8
# The index of the K nearest neighbours are: [ 296 3071  780 3923 1009]
# The labels for the index before are: [ 8  8  9 10 10]
# The KNN categories are : ['rec.motorcycles' 'rec.motorcycles' 'rec.sport.baseball'
#  'rec.sport.hockey' 'rec.sport.hockey']
# The final label is: 8
# The index of the K nearest neighbours are: [5816 2775 2336 5293 3533]
# The labels for the index before are: [ 5 19  8  2 13]
# The KNN categories are : ['comp.windows.x' 'talk.religion.misc' 'rec.motorcycles'
#  'comp.os.ms-windows.misc' 'sci.med']
# The final label is: 5
# The index of the K nearest neighbours are: [4158 5606 1204 2131  751]
# The labels for the index before are: [18 18  1 13 12]
# The KNN categories are : ['talk.politics.misc' 'talk.politics.misc' 'comp.graphics' 'sci.med'
#  'sci.electronics']
# The final label is: 18
# The index of the K nearest neighbours are: [4831 5448 5394 5762 4874]
# The labels for the index before are: [18  2  6  4 18]
# The KNN categories are : ['talk.politics.misc' 'comp.os.ms-windows.misc' 'misc.forsale'
#  'comp.sys.mac.hardware' 'talk.politics.misc']
# The final label is: 18
# The index of the K nearest neighbours are: [3853 2222 3578  460 5986]
# The labels for the index before are: [ 4 19 11 15 12]
# The KNN categories are : ['comp.sys.mac.hardware' 'talk.religion.misc' 'sci.crypt'
#  'soc.religion.christian' 'sci.electronics']
# The final label is: 4
# The index of the K nearest neighbours are: [6101 1015 5372 2834 4721]
# The labels for the index before are: [17 10  5  5 14]
# The KNN categories are : ['talk.politics.mideast' 'rec.sport.hockey' 'comp.windows.x'
#  'comp.windows.x' 'sci.space']
# The final label is: 5
# The index of the K nearest neighbours are: [3258 7281 2022 3010 7192]
# The labels for the index before are: [ 3  2  9  6 15]
# The KNN categories are : ['comp.sys.ibm.pc.hardware' 'comp.os.ms-windows.misc' 'rec.sport.baseball'
#  'misc.forsale' 'soc.religion.christian']
# The final label is: 3
# The index of the K nearest neighbours are: [3346 7223 7372 4120 3451]
# The labels for the index before are: [ 5 10  3 10 15]
# The KNN categories are : ['comp.windows.x' 'rec.sport.hockey' 'comp.sys.ibm.pc.hardware'
#  'rec.sport.hockey' 'soc.religion.christian']
# The final label is: 10
# The index of the K nearest neighbours are: [2693 4612 3050 2472 4620]
# The labels for the index before are: [ 4  6 14  4  1]
# The KNN categories are : ['comp.sys.mac.hardware' 'misc.forsale' 'sci.space' 'comp.sys.mac.hardware'
#  'comp.graphics']
# The final label is: 4
# The index of the K nearest neighbours are: [3810 6076 4428 3262 2706]
# The labels for the index before are: [17  8  1  0 14]
# The KNN categories are : ['talk.politics.mideast' 'rec.motorcycles' 'comp.graphics' 'alt.atheism'
#  'sci.space']
# The final label is: 17
# The index of the K nearest neighbours are: [6135 4180 4280 2239 5198]
# The labels for the index before are: [18  2  2 16 12]
# The KNN categories are : ['talk.politics.misc' 'comp.os.ms-windows.misc' 'comp.os.ms-windows.misc'
#  'talk.politics.guns' 'sci.electronics']
# The final label is: 2
# The index of the K nearest neighbours are: [3740 3895 1193 1238 3987]
# The labels for the index before are: [ 6  1 13  6  6]
# The KNN categories are : ['misc.forsale' 'comp.graphics' 'sci.med' 'misc.forsale' 'misc.forsale']
# The final label is: 6
# The index of the K nearest neighbours are: [3925 4978 1275 6339 4372]
# The labels for the index before are: [ 6 14 11  8 11]
# The KNN categories are : ['misc.forsale' 'sci.space' 'sci.crypt' 'rec.motorcycles' 'sci.crypt']
# The final label is: 11
# The index of the K nearest neighbours are: [  21 5692  441 2858 3615]
# The labels for the index before are: [ 6  6 18 13  8]
# The KNN categories are : ['misc.forsale' 'misc.forsale' 'talk.politics.misc' 'sci.med'
#  'rec.motorcycles']
# The final label is: 6
# The index of the K nearest neighbours are: [ 229 3677 3868 7164 5426]
# The labels for the index before are: [ 7  1 11  2 14]
# The KNN categories are : ['rec.autos' 'comp.graphics' 'sci.crypt' 'comp.os.ms-windows.misc'
#  'sci.space']
# The final label is: 7
# The index of the K nearest neighbours are: [1349 4010 5088 3023 5273]
# The labels for the index before are: [ 4 13  9  3  8]
# The KNN categories are : ['comp.sys.mac.hardware' 'sci.med' 'rec.sport.baseball'
#  'comp.sys.ibm.pc.hardware' 'rec.motorcycles']
# The final label is: 4
# The index of the K nearest neighbours are: [ 731 3927 2508 3897  770]
# The labels for the index before are: [12 15 16 11 19]
# The KNN categories are : ['sci.electronics' 'soc.religion.christian' 'talk.politics.guns'
#  'sci.crypt' 'talk.religion.misc']
# The final label is: 12
# The index of the K nearest neighbours are: [6572 3295  533 7465  510]
# The labels for the index before are: [ 7  8 13  6 14]
# The KNN categories are : ['rec.autos' 'rec.motorcycles' 'sci.med' 'misc.forsale' 'sci.space']
# The final label is: 7
# The index of the K nearest neighbours are: [ 649 6894 5895  817  101]
# The labels for the index before are: [ 1 15  1  2 10]
# The KNN categories are : ['comp.graphics' 'soc.religion.christian' 'comp.graphics'
#  'comp.os.ms-windows.misc' 'rec.sport.hockey']
# The final label is: 1
# The index of the K nearest neighbours are: [7303  370 6004 2667 6778]
# The labels for the index before are: [ 8 18 19 14 17]
# The KNN categories are : ['rec.motorcycles' 'talk.politics.misc' 'talk.religion.misc' 'sci.space'
#  'talk.politics.mideast']
# The final label is: 8
# The index of the K nearest neighbours are: [3029 2574 3342 1517 5622]
# The labels for the index before are: [ 4 11 15 11  5]
# The KNN categories are : ['comp.sys.mac.hardware' 'sci.crypt' 'soc.religion.christian' 'sci.crypt'
#  'comp.windows.x']
# The final label is: 11
# The index of the K nearest neighbours are: [4689 7477 6836 7141 3125]
# The labels for the index before are: [15  7 10 11 12]
# The KNN categories are : ['soc.religion.christian' 'rec.autos' 'rec.sport.hockey' 'sci.crypt'
#  'sci.electronics']
# The final label is: 15
# The index of the K nearest neighbours are: [6401 2100 5050 5335 3737]
# The labels for the index before are: [ 9 13 17 10 11]
# The KNN categories are : ['rec.sport.baseball' 'sci.med' 'talk.politics.mideast' 'rec.sport.hockey'
#  'sci.crypt']
# The final label is: 9
# The index of the K nearest neighbours are: [3039 7455 6734 4216  843]
# The labels for the index before are: [ 2 17 17 13  6]
# The KNN categories are : ['comp.os.ms-windows.misc' 'talk.politics.mideast' 'talk.politics.mideast'
#  'sci.med' 'misc.forsale']
# The final label is: 17
# The index of the K nearest neighbours are: [1175 4434 5728 6608 4005]
# The labels for the index before are: [17 15 10  6  3]
# The KNN categories are : ['talk.politics.mideast' 'soc.religion.christian' 'rec.sport.hockey'
#  'misc.forsale' 'comp.sys.ibm.pc.hardware']
# The final label is: 17
# The index of the K nearest neighbours are: [7129 2294 4228 4520 5243]
# The labels for the index before are: [ 8 11  6  0 15]
# The KNN categories are : ['rec.motorcycles' 'sci.crypt' 'misc.forsale' 'alt.atheism'
#  'soc.religion.christian']
# The final label is: 8
# The index of the K nearest neighbours are: [1699 6973 1833 4123 6782]
# The labels for the index before are: [17  5  9 10  6]
# The KNN categories are : ['talk.politics.mideast' 'comp.windows.x' 'rec.sport.baseball'
#  'rec.sport.hockey' 'misc.forsale']
# The final label is: 17
# The index of the K nearest neighbours are: [6495 6608 3920 5728 3199]
# The labels for the index before are: [13  6 11 10  5]
# The KNN categories are : ['sci.med' 'misc.forsale' 'sci.crypt' 'rec.sport.hockey' 'comp.windows.x']
# The final label is: 13
# The index of the K nearest neighbours are: [5774 6172 2696 4771 6763]
# The labels for the index before are: [11  7  1  5 16]
# The KNN categories are : ['sci.crypt' 'rec.autos' 'comp.graphics' 'comp.windows.x'
#  'talk.politics.guns']
# The final label is: 11
# The index of the K nearest neighbours are: [7415  227 3399 3426 2831]
# The labels for the index before are: [ 2  2 17  3  7]
# The KNN categories are : ['comp.os.ms-windows.misc' 'comp.os.ms-windows.misc'
#  'talk.politics.mideast' 'comp.sys.ibm.pc.hardware' 'rec.autos']
# The final label is: 2
# The index of the K nearest neighbours are: [4983 5917 2500 2173 1034]
# The labels for the index before are: [ 5 13 15 13 14]
# The KNN categories are : ['comp.windows.x' 'sci.med' 'soc.religion.christian' 'sci.med' 'sci.space']
# The final label is: 13
# The index of the K nearest neighbours are: [4826  154  189 6114 4445]
# The labels for the index before are: [ 8  6 12  2 10]
# The KNN categories are : ['rec.motorcycles' 'misc.forsale' 'sci.electronics'
#  'comp.os.ms-windows.misc' 'rec.sport.hockey']
# The final label is: 8
# The index of the K nearest neighbours are: [6931 1073 3513 2955 2150]
# The labels for the index before are: [14  1  6  4 16]
# The KNN categories are : ['sci.space' 'comp.graphics' 'misc.forsale' 'comp.sys.mac.hardware'
#  'talk.politics.guns']
# The final label is: 14
# The index of the K nearest neighbours are: [2021 1135 3432 3347 3041]
# The labels for the index before are: [17  4 11 15  8]
# The KNN categories are : ['talk.politics.mideast' 'comp.sys.mac.hardware' 'sci.crypt'
#  'soc.religion.christian' 'rec.motorcycles']
# The final label is: 17
# The index of the K nearest neighbours are: [5842 2449 3529  904 1562]
# The labels for the index before are: [ 9  6 19 19  4]
# The KNN categories are : ['rec.sport.baseball' 'misc.forsale' 'talk.religion.misc'
#  'talk.religion.misc' 'comp.sys.mac.hardware']
# The final label is: 19
# The index of the K nearest neighbours are: [7124 5591 5458 6699 1254]
# The labels for the index before are: [ 2  7 12 13  3]
# The KNN categories are : ['comp.os.ms-windows.misc' 'rec.autos' 'sci.electronics' 'sci.med'
#  'comp.sys.ibm.pc.hardware']
# The final label is: 2
# The index of the K nearest neighbours are: [5844 1182 4498 5612 5856]
# The labels for the index before are: [ 6  6  4 11  1]
# The KNN categories are : ['misc.forsale' 'misc.forsale' 'comp.sys.mac.hardware' 'sci.crypt'
#  'comp.graphics']
# The final label is: 6
# The index of the K nearest neighbours are: [6204 7148 4714 6546 6078]
# The labels for the index before are: [ 9  3  8 14  6]
# The KNN categories are : ['rec.sport.baseball' 'comp.sys.ibm.pc.hardware' 'rec.motorcycles'
#  'sci.space' 'misc.forsale']
# The final label is: 9
# The index of the K nearest neighbours are: [1589 5439  375 3108 6711]
# The labels for the index before are: [ 9  6 14 14 18]
# The KNN categories are : ['rec.sport.baseball' 'misc.forsale' 'sci.space' 'sci.space'
#  'talk.politics.misc']
# The final label is: 14
# The index of the K nearest neighbours are: [3816 1734 2080 4920 5535]
# The labels for the index before are: [7 9 2 9 3]
# The KNN categories are : ['rec.autos' 'rec.sport.baseball' 'comp.os.ms-windows.misc'
#  'rec.sport.baseball' 'comp.sys.ibm.pc.hardware']
# The final label is: 9
# The index of the K nearest neighbours are: [3730 4740 1025  621 5205]
# The labels for the index before are: [10  8  9 14 18]
# The KNN categories are : ['rec.sport.hockey' 'rec.motorcycles' 'rec.sport.baseball' 'sci.space'
#  'talk.politics.misc']
# The final label is: 10
# The index of the K nearest neighbours are: [3244 3178 1304 4752  653]
# The labels for the index before are: [ 2  6 10  3  6]
# The KNN categories are : ['comp.os.ms-windows.misc' 'misc.forsale' 'rec.sport.hockey'
#  'comp.sys.ibm.pc.hardware' 'misc.forsale']
# The final label is: 6
# The index of the K nearest neighbours are: [5429 1246  847 5028 4049]
# The labels for the index before are: [ 0 18 17 10  7]
# The KNN categories are : ['alt.atheism' 'talk.politics.misc' 'talk.politics.mideast'
#  'rec.sport.hockey' 'rec.autos']
# The final label is: 0
# The index of the K nearest neighbours are: [1239 2071 5599 5090 5352]
# The labels for the index before are: [ 2  6  3 15  6]
# The KNN categories are : ['comp.os.ms-windows.misc' 'misc.forsale' 'comp.sys.ibm.pc.hardware'
#  'soc.religion.christian' 'misc.forsale']
# The final label is: 6
# The index of the K nearest neighbours are: [7370 6625 3427 6357  754]
# The labels for the index before are: [14 19 16 10 10]
# The KNN categories are : ['sci.space' 'talk.religion.misc' 'talk.politics.guns' 'rec.sport.hockey'
#  'rec.sport.hockey']
# The final label is: 10
# The index of the K nearest neighbours are: [2928 7416  384 3748 4452]
# The labels for the index before are: [12 11  6 15 12]
# The KNN categories are : ['sci.electronics' 'sci.crypt' 'misc.forsale' 'soc.religion.christian'
#  'sci.electronics']
# The final label is: 12
# The index of the K nearest neighbours are: [ 617 1674  388 6627 5507]
# The labels for the index before are: [ 7 16  7  7  0]
# The KNN categories are : ['rec.autos' 'talk.politics.guns' 'rec.autos' 'rec.autos' 'alt.atheism']
# The final label is: 7
# The index of the K nearest neighbours are: [5865  596 7278 2335 7319]
# The labels for the index before are: [15 18  3  7  0]
# The KNN categories are : ['soc.religion.christian' 'talk.politics.misc' 'comp.sys.ibm.pc.hardware'
#  'rec.autos' 'alt.atheism']
# The final label is: 15
# The index of the K nearest neighbours are: [4260 5393 5850 2628 4524]
# The labels for the index before are: [ 1 15  7  4 13]
# The KNN categories are : ['comp.graphics' 'soc.religion.christian' 'rec.autos'
#  'comp.sys.mac.hardware' 'sci.med']
# The final label is: 1
# The index of the K nearest neighbours are: [1297 3636 3679  807 6434]
# The labels for the index before are: [ 2 15 17 17  8]
# The KNN categories are : ['comp.os.ms-windows.misc' 'soc.religion.christian' 'talk.politics.mideast'
#  'talk.politics.mideast' 'rec.motorcycles']
# The final label is: 17
# The index of the K nearest neighbours are: [2788 1411 5861 3368 6239]
# The labels for the index before are: [11  6  4  9  9]
# The KNN categories are : ['sci.crypt' 'misc.forsale' 'comp.sys.mac.hardware' 'rec.sport.baseball'
#  'rec.sport.baseball']
# The final label is: 9
# The index of the K nearest neighbours are: [5245 6779  573 7342 2520]
# The labels for the index before are: [ 7 12 17  2  5]
# The KNN categories are : ['rec.autos' 'sci.electronics' 'talk.politics.mideast'
#  'comp.os.ms-windows.misc' 'comp.windows.x']
# The final label is: 7
# The index of the K nearest neighbours are: [4886 5943 7054 2254 4511]
# The labels for the index before are: [ 6 10  5 13  3]
# The KNN categories are : ['misc.forsale' 'rec.sport.hockey' 'comp.windows.x' 'sci.med'
#  'comp.sys.ibm.pc.hardware']
# The final label is: 6
# The index of the K nearest neighbours are: [7442 3298 6634 2270 6269]
# The labels for the index before are: [13  9  3  4  8]
# The KNN categories are : ['sci.med' 'rec.sport.baseball' 'comp.sys.ibm.pc.hardware'
#  'comp.sys.mac.hardware' 'rec.motorcycles']
# The final label is: 13
# The index of the K nearest neighbours are: [6572 3295  533 7465  510]
# The labels for the index before are: [ 7  8 13  6 14]
# The KNN categories are : ['rec.autos' 'rec.motorcycles' 'sci.med' 'misc.forsale' 'sci.space']
# The final label is: 7
# The index of the K nearest neighbours are: [ 867 2358 1159 5956 1251]
# The labels for the index before are: [16 11  7 18 15]
# The KNN categories are : ['talk.politics.guns' 'sci.crypt' 'rec.autos' 'talk.politics.misc'
#  'soc.religion.christian']
# The final label is: 16
# The index of the K nearest neighbours are: [5048 4387  384 6585 6001]
# The labels for the index before are: [ 4 10  6  3  7]
# The KNN categories are : ['comp.sys.mac.hardware' 'rec.sport.hockey' 'misc.forsale'
#  'comp.sys.ibm.pc.hardware' 'rec.autos']
# The final label is: 4
# The index of the K nearest neighbours are: [7064  558 7108  341 1675]
# The labels for the index before are: [ 4 10  4 10 18]
# The KNN categories are : ['comp.sys.mac.hardware' 'rec.sport.hockey' 'comp.sys.mac.hardware'
#  'rec.sport.hockey' 'talk.politics.misc']
# The final label is: 4
# The index of the K nearest neighbours are: [1834 2747 1186 7407 1429]
# The labels for the index before are: [2 1 1 9 9]
# The KNN categories are : ['comp.os.ms-windows.misc' 'comp.graphics' 'comp.graphics'
#  'rec.sport.baseball' 'rec.sport.baseball']
# The final label is: 1
# The index of the K nearest neighbours are: [3556 2357 1007 4295 3207]
# The labels for the index before are: [ 3 10 15  9  1]
# The KNN categories are : ['comp.sys.ibm.pc.hardware' 'rec.sport.hockey' 'soc.religion.christian'
#  'rec.sport.baseball' 'comp.graphics']
# The final label is: 3
# The index of the K nearest neighbours are: [3791 7019 4574 2008 1238]
# The labels for the index before are: [7 8 3 0 6]
# The KNN categories are : ['rec.autos' 'rec.motorcycles' 'comp.sys.ibm.pc.hardware' 'alt.atheism'
#  'misc.forsale']
# The final label is: 7
# The index of the K nearest neighbours are: [5536 3575 3896 7529 4861]
# The labels for the index before are: [ 2  1 13  9  8]
# The KNN categories are : ['comp.os.ms-windows.misc' 'comp.graphics' 'sci.med' 'rec.sport.baseball'
#  'rec.motorcycles']
# The final label is: 2
# The index of the K nearest neighbours are: [3995 7528  263  951 4212]
# The labels for the index before are: [18  4  8 13 17]
# The KNN categories are : ['talk.politics.misc' 'comp.sys.mac.hardware' 'rec.motorcycles' 'sci.med'
#  'talk.politics.mideast']
# The final label is: 18
# The index of the K nearest neighbours are: [5388 5604 1720 6504 1958]
# The labels for the index before are: [12 19  0  6  6]
# The KNN categories are : ['sci.electronics' 'talk.religion.misc' 'alt.atheism' 'misc.forsale'
#  'misc.forsale']
# The final label is: 6
# The index of the K nearest neighbours are: [6375  318 3711 4521  155]
# The labels for the index before are: [16  9 14  3 14]
# The KNN categories are : ['talk.politics.guns' 'rec.sport.baseball' 'sci.space'
#  'comp.sys.ibm.pc.hardware' 'sci.space']
# The final label is: 14
# The index of the K nearest neighbours are: [6553 2831  357 2525 7334]
# The labels for the index before are: [ 9  7 18  1  9]
# The KNN categories are : ['rec.sport.baseball' 'rec.autos' 'talk.politics.misc' 'comp.graphics'
#  'rec.sport.baseball']
# The final label is: 9
# The index of the K nearest neighbours are: [1519 4910  747 4622 6202]
# The labels for the index before are: [15 18 11  5 16]
# The KNN categories are : ['soc.religion.christian' 'talk.politics.misc' 'sci.crypt' 'comp.windows.x'
#  'talk.politics.guns']
# The final label is: 15
# The index of the K nearest neighbours are: [4726 6103 6098 1546 3961]
# The labels for the index before are: [12  6  6 12 17]
# The KNN categories are : ['sci.electronics' 'misc.forsale' 'misc.forsale' 'sci.electronics'
#  'talk.politics.mideast']
# The final label is: 12
# The index of the K nearest neighbours are: [3847 5955 7499  908 5077]
# The labels for the index before are: [ 3  4  3  3 11]
# The KNN categories are : ['comp.sys.ibm.pc.hardware' 'comp.sys.mac.hardware'
#  'comp.sys.ibm.pc.hardware' 'comp.sys.ibm.pc.hardware' 'sci.crypt']
# The final label is: 3
# The index of the K nearest neighbours are: [3762 6858 1511 2094 6590]
# The labels for the index before are: [10 16  3  4 14]
# The KNN categories are : ['rec.sport.hockey' 'talk.politics.guns' 'comp.sys.ibm.pc.hardware'
#  'comp.sys.mac.hardware' 'sci.space']
# The final label is: 10
# The index of the K nearest neighbours are: [2725 5985 4359 2641 1684]
# The labels for the index before are: [13  9 14  9 13]
# The KNN categories are : ['sci.med' 'rec.sport.baseball' 'sci.space' 'rec.sport.baseball' 'sci.med']
# The final label is: 13
# The index of the K nearest neighbours are: [1578 7298 5611 4135 2349]
# The labels for the index before are: [ 5 11 12  4 10]
# The KNN categories are : ['comp.windows.x' 'sci.crypt' 'sci.electronics' 'comp.sys.mac.hardware'
#  'rec.sport.hockey']
# The final label is: 5
# The index of the K nearest neighbours are: [ 730 6418 3886 4883 1224]
# The labels for the index before are: [14 10 10 17 14]
# The KNN categories are : ['sci.space' 'rec.sport.hockey' 'rec.sport.hockey' 'talk.politics.mideast'
#  'sci.space']
# The final label is: 14
# The index of the K nearest neighbours are: [1050 5776 3640 3658 4513]
# The labels for the index before are: [16 11  6  1  7]
# The KNN categories are : ['talk.politics.guns' 'sci.crypt' 'misc.forsale' 'comp.graphics'
#  'rec.autos']
# ...
# The final label is: 14
# The index of the K nearest neighbours are: [1855 7441 2212 4350 6543]
# The labels for the index before are: [15  3  5  9 18]
# The KNN categories are : ['soc.religion.christian' 'comp.sys.ibm.pc.hardware' 'comp.windows.x'
#  'rec.sport.baseball' 'talk.politics.misc']
# The final label is: 15
# The index of the K nearest neighbours are: [2306 5227 1345 2301 4986]
# The labels for the index before are: [ 5  4  8 17 15]
# The KNN categories are : ['comp.windows.x' 'comp.sys.mac.hardware' 'rec.motorcycles'
#  'talk.politics.mideast' 'soc.religion.christian']
# The final label is: 5
# The index of the K nearest neighbours are: [3498  478 4398 6149 6918]
# The labels for the index before are: [ 0  7 17  0 17]
# The KNN categories are : ['alt.atheism' 'rec.autos' 'talk.politics.mideast' 'alt.atheism'
#  'talk.politics.mideast']
# The final label is: 0
# The index of the K nearest neighbours are: [5962 2481 6447  485 4609]
# The labels for the index before are: [14  1 12  5  4]
# The KNN categories are : ['sci.space' 'comp.graphics' 'sci.electronics' 'comp.windows.x'
#  'comp.sys.mac.hardware']
# The final label is: 14
# The index of the K nearest neighbours are: [ 119 6192 2301 5413 4986]
# The labels for the index before are: [17  2 17  9 15]
# The KNN categories are : ['talk.politics.mideast' 'comp.os.ms-windows.misc' 'talk.politics.mideast'
#  'rec.sport.baseball' 'soc.religion.christian']
# The final label is: 17
# The index of the K nearest neighbours are: [5013  194  908  428 3847]
# The labels for the index before are: [15  3  3  8  3]
# The KNN categories are : ['soc.religion.christian' 'comp.sys.ibm.pc.hardware'
#  'comp.sys.ibm.pc.hardware' 'rec.motorcycles' 'comp.sys.ibm.pc.hardware']
# The final label is: 3
# The index of the K nearest neighbours are: [4791 5587 1676 3469  244]
# The labels for the index before are: [14  1  0  3 14]
# The KNN categories are : ['sci.space' 'comp.graphics' 'alt.atheism' 'comp.sys.ibm.pc.hardware'
#  'sci.space']
# The final label is: 14
# The index of the K nearest neighbours are: [3980 2832 5956 3777 5498]
# The labels for the index before are: [ 7  9 18 13  2]
# The KNN categories are : ['rec.autos' 'rec.sport.baseball' 'talk.politics.misc' 'sci.med'
#  'comp.os.ms-windows.misc']
# The final label is: 7
# The index of the K nearest neighbours are: [3743  891 5434   68 5084]
# The labels for the index before are: [10 14  3  0  2]
# The KNN categories are : ['rec.sport.hockey' 'sci.space' 'comp.sys.ibm.pc.hardware' 'alt.atheism'
#  'comp.os.ms-windows.misc']
# The final label is: 10
# The index of the K nearest neighbours are: [2163 2235 5592 1532 2271]
# The labels for the index before are: [ 0  3 12  0 18]
# The KNN categories are : ['alt.atheism' 'comp.sys.ibm.pc.hardware' 'sci.electronics' 'alt.atheism'
#  'talk.politics.misc']
# The final label is: 0
# The index of the K nearest neighbours are: [ 796 5236 4880 2309 4609]
# The labels for the index before are: [9 4 9 5 4]
# The KNN categories are : ['rec.sport.baseball' 'comp.sys.mac.hardware' 'rec.sport.baseball'
#  'comp.windows.x' 'comp.sys.mac.hardware']
# The final label is: 9
# The index of the K nearest neighbours are: [1250 5667  994 1688 3292]
# The labels for the index before are: [ 3 18  0  7 11]
# The KNN categories are : ['comp.sys.ibm.pc.hardware' 'talk.politics.misc' 'alt.atheism' 'rec.autos'
#  'sci.crypt']
# The final label is: 3
# The index of the K nearest neighbours are: [ 664 5712 1485 2458 3327]
# The labels for the index before are: [10 17  9  4 18]
# The KNN categories are : ['rec.sport.hockey' 'talk.politics.mideast' 'rec.sport.baseball'
#  'comp.sys.mac.hardware' 'talk.politics.misc']
# The final label is: 10
# The index of the K nearest neighbours are: [1919 4036  298 1558 3635]
# The labels for the index before are: [ 5 17  9  2 10]
# The KNN categories are : ['comp.windows.x' 'talk.politics.mideast' 'rec.sport.baseball'
#  'comp.os.ms-windows.misc' 'rec.sport.hockey']
# The final label is: 5
# The index of the K nearest neighbours are: [7089  537 7148  202 1804]
# The labels for the index before are: [ 9  9  3  4 16]
# The KNN categories are : ['rec.sport.baseball' 'rec.sport.baseball' 'comp.sys.ibm.pc.hardware'
#  'comp.sys.mac.hardware' 'talk.politics.guns']
# The final label is: 9
# The index of the K nearest neighbours are: [2945 2105  874 7421 2997]
# The labels for the index before are: [15  1  1 18  6]
# The KNN categories are : ['soc.religion.christian' 'comp.graphics' 'comp.graphics'
#  'talk.politics.misc' 'misc.forsale']
# The final label is: 1
# The index of the K nearest neighbours are: [6979 5906 4336 7530  710]
# The labels for the index before are: [ 8 10  1  6 19]
# The KNN categories are : ['rec.motorcycles' 'rec.sport.hockey' 'comp.graphics' 'misc.forsale'
#  'talk.religion.misc']
# The final label is: 8
# The index of the K nearest neighbours are: [1295 6348 1290 4374 5127]
# The labels for the index before are: [ 5  8 13  1  8]
# The KNN categories are : ['comp.windows.x' 'rec.motorcycles' 'sci.med' 'comp.graphics'
#  'rec.motorcycles']
# The final label is: 8
# The index of the K nearest neighbours are: [5478 3361 5454 3340   70]
# The labels for the index before are: [ 4 19  4 11  8]
# The KNN categories are : ['comp.sys.mac.hardware' 'talk.religion.misc' 'comp.sys.mac.hardware'
#  'sci.crypt' 'rec.motorcycles']
# The final label is: 4
# The index of the K nearest neighbours are: [5630 6515 5029  820 1242]
# The labels for the index before are: [ 9  7  5 13  1]
# The KNN categories are : ['rec.sport.baseball' 'rec.autos' 'comp.windows.x' 'sci.med'
#  'comp.graphics']
# The final label is: 9
# The index of the K nearest neighbours are: [1542 3115 5823 5918 4823]
# The labels for the index before are: [10  8 14 14  3]
# The KNN categories are : ['rec.sport.hockey' 'rec.motorcycles' 'sci.space' 'sci.space'
#  'comp.sys.ibm.pc.hardware']
# The final label is: 14
# The index of the K nearest neighbours are: [5898 1735 2586 6243 4139]
# The labels for the index before are: [ 6 16 11  9 10]
# The KNN categories are : ['misc.forsale' 'talk.politics.guns' 'sci.crypt' 'rec.sport.baseball'
#  'rec.sport.hockey']
# The final label is: 6
# The index of the K nearest neighbours are: [7154 7340 6700 5159 2328]
# The labels for the index before are: [ 5 15  1  1  4]
# The KNN categories are : ['comp.windows.x' 'soc.religion.christian' 'comp.graphics' 'comp.graphics'
#  'comp.sys.mac.hardware']
# The final label is: 1
# The index of the K nearest neighbours are: [ 502 7478  949 6977 4582]
# The labels for the index before are: [9 6 8 7 4]
# The KNN categories are : ['rec.sport.baseball' 'misc.forsale' 'rec.motorcycles' 'rec.autos'
#  'comp.sys.mac.hardware']
# The final label is: 9
# The index of the K nearest neighbours are: [2751 7252 7106 2210 3785]
# The labels for the index before are: [15  4  5  5  2]
# The KNN categories are : ['soc.religion.christian' 'comp.sys.mac.hardware' 'comp.windows.x'
#  'comp.windows.x' 'comp.os.ms-windows.misc']
# The final label is: 5
# The index of the K nearest neighbours are: [3392 4929 4193 6148 4906]
# The labels for the index before are: [ 0 19 11  9 16]
# The KNN categories are : ['alt.atheism' 'talk.religion.misc' 'sci.crypt' 'rec.sport.baseball'
#  'talk.politics.guns']
# The final label is: 0
# The index of the K nearest neighbours are: [3219 1511 6933 7415  554]
# The labels for the index before are: [ 4  3 19  2 10]
# The KNN categories are : ['comp.sys.mac.hardware' 'comp.sys.ibm.pc.hardware' 'talk.religion.misc'
#  'comp.os.ms-windows.misc' 'rec.sport.hockey']
# The final label is: 4
# The index of the K nearest neighbours are: [ 731 3927 2508 3897  770]
# The labels for the index before are: [12 15 16 11 19]
# The KNN categories are : ['sci.electronics' 'soc.religion.christian' 'talk.politics.guns'
#  'sci.crypt' 'talk.religion.misc']
# The final label is: 12
# The index of the K nearest neighbours are: [ 301 1418 5904 5878  955]
# The labels for the index before are: [ 0  5 11 17 10]
# The KNN categories are : ['alt.atheism' 'comp.windows.x' 'sci.crypt' 'talk.politics.mideast'
#  'rec.sport.hockey']
# The final label is: 0
# The index of the K nearest neighbours are: [1048 1946 3971 4088 5278]
# The labels for the index before are: [10  9  2  5  6]
# The KNN categories are : ['rec.sport.hockey' 'rec.sport.baseball' 'comp.os.ms-windows.misc'
#  'comp.windows.x' 'misc.forsale']
# The final label is: 10
# The index of the K nearest neighbours are: [3803 4685 6074 7399  636]
# The labels for the index before are: [ 9 12  6  9 11]
# The KNN categories are : ['rec.sport.baseball' 'sci.electronics' 'misc.forsale' 'rec.sport.baseball'
#  'sci.crypt']
# The final label is: 9
# The index of the K nearest neighbours are: [3280  809 2043   51 6706]
# The labels for the index before are: [16 16  2  8 12]
# The KNN categories are : ['talk.politics.guns' 'talk.politics.guns' 'comp.os.ms-windows.misc'
#  'rec.motorcycles' 'sci.electronics']
# The final label is: 16
# The index of the K nearest neighbours are: [4250 6413 6736 4330 7208]
# The labels for the index before are: [ 5  9  8  1 15]
# The KNN categories are : ['comp.windows.x' 'rec.sport.baseball' 'rec.motorcycles' 'comp.graphics'
#  'soc.religion.christian']
# The final label is: 5
# The index of the K nearest neighbours are: [6637 1244 1782 2559 1414]
# The labels for the index before are: [ 8  5 17  1  9]
# The KNN categories are : ['rec.motorcycles' 'comp.windows.x' 'talk.politics.mideast' 'comp.graphics'
#  'rec.sport.baseball']
# The final label is: 8
# The index of the K nearest neighbours are: [1938 4129 6025 1849  895]
# The labels for the index before are: [16 19 15 15  3]
# The KNN categories are : ['talk.politics.guns' 'talk.religion.misc' 'soc.religion.christian'
#  'soc.religion.christian' 'comp.sys.ibm.pc.hardware']
# The final label is: 15
# The index of the K nearest neighbours are: [ 414 5636  651 6298 5784]
# The labels for the index before are: [12  8 17  8 13]
# The KNN categories are : ['sci.electronics' 'rec.motorcycles' 'talk.politics.mideast'
#  'rec.motorcycles' 'sci.med']
# The final label is: 8
# The index of the K nearest neighbours are: [3760 2418 5747 1097 4529]
# The labels for the index before are: [ 2  0  6 17  9]
# The KNN categories are : ['comp.os.ms-windows.misc' 'alt.atheism' 'misc.forsale'
#  'talk.politics.mideast' 'rec.sport.baseball']
# The final label is: 2
# The index of the K nearest neighbours are: [ 528 7169 7042 1723 2805]
# The labels for the index before are: [13 12  8  5  6]
# The KNN categories are : ['sci.med' 'sci.electronics' 'rec.motorcycles' 'comp.windows.x'
#  'misc.forsale']
# The final label is: 13
# The index of the K nearest neighbours are: [4859 5745 1128 5360 3864]
# The labels for the index before are: [ 0 15  7  7 16]
# The KNN categories are : ['alt.atheism' 'soc.religion.christian' 'rec.autos' 'rec.autos'
#  'talk.politics.guns']
# The final label is: 7
# The index of the K nearest neighbours are: [4183 6193 3864 3682 1388]
# The labels for the index before are: [19 18 16  1  0]
# The KNN categories are : ['talk.religion.misc' 'talk.politics.misc' 'talk.politics.guns'
#  'comp.graphics' 'alt.atheism']
# The final label is: 19
# The index of the K nearest neighbours are: [6259 5022 2605 1144 5454]
# The labels for the index before are: [16 16  4 11  4]
# The KNN categories are : ['talk.politics.guns' 'talk.politics.guns' 'comp.sys.mac.hardware'
#  'sci.crypt' 'comp.sys.mac.hardware']
# The final label is: 16
# The index of the K nearest neighbours are: [4181 7348 6523 4347 2552]
# The labels for the index before are: [ 6 10  5 10 19]
# The KNN categories are : ['misc.forsale' 'rec.sport.hockey' 'comp.windows.x' 'rec.sport.hockey'
#  'talk.religion.misc']
# The final label is: 10
# The index of the K nearest neighbours are: [4741 7433 5353 2573  906]
# The labels for the index before are: [ 8  1 15  9 14]
# The KNN categories are : ['rec.motorcycles' 'comp.graphics' 'soc.religion.christian'
#  'rec.sport.baseball' 'sci.space']
# The final label is: 8
# The index of the K nearest neighbours are: [6544 5691  876 3033 3413]
# The labels for the index before are: [ 4 10  3 18  7]
# The KNN categories are : ['comp.sys.mac.hardware' 'rec.sport.hockey' 'comp.sys.ibm.pc.hardware'
#  'talk.politics.misc' 'rec.autos']
# The final label is: 4
# The index of the K nearest neighbours are: [6922 1707  220 3551  778]
# The labels for the index before are: [13 12  7  6 12]
# The KNN categories are : ['sci.med' 'sci.electronics' 'rec.autos' 'misc.forsale' 'sci.electronics']
# The final label is: 12
# The index of the K nearest neighbours are: [2353 4268 6997 1687 4668]
# The labels for the index before are: [14 12 12  6 19]
# The KNN categories are : ['sci.space' 'sci.electronics' 'sci.electronics' 'misc.forsale'
#  'talk.religion.misc']
# The final label is: 12
# The index of the K nearest neighbours are: [  53 4619 6423 7213 4758]
# The labels for the index before are: [ 9 17  9 14  0]
# The KNN categories are : ['rec.sport.baseball' 'talk.politics.mideast' 'rec.sport.baseball'
#  'sci.space' 'alt.atheism']
# The final label is: 9
# The index of the K nearest neighbours are: [6087 6945 1146 2714 4633]
# The labels for the index before are: [19  6  1  4 13]
# The KNN categories are : ['talk.religion.misc' 'misc.forsale' 'comp.graphics'
#  'comp.sys.mac.hardware' 'sci.med']
# The final label is: 19
# The index of the K nearest neighbours are: [ 959 3223 5281 5525 5450]
# The labels for the index before are: [ 7 16  3 15 18]
# The KNN categories are : ['rec.autos' 'talk.politics.guns' 'comp.sys.ibm.pc.hardware'
#  'soc.religion.christian' 'talk.politics.misc']
# The final label is: 7
# The index of the K nearest neighbours are: [4986 3837 1872 2301 4535]
# The labels for the index before are: [15 17 11 17 18]
# The KNN categories are : ['soc.religion.christian' 'talk.politics.mideast' 'sci.crypt'
#  'talk.politics.mideast' 'talk.politics.misc']
# The final label is: 17
# The index of the K nearest neighbours are: [1060 2657 2035 4778 4203]
# The labels for the index before are: [9 0 5 2 8]
# The KNN categories are : ['rec.sport.baseball' 'alt.atheism' 'comp.windows.x'
#  'comp.os.ms-windows.misc' 'rec.motorcycles']
# The final label is: 9
# The index of the K nearest neighbours are: [ 998 2963 7213 1338 4946]
# The labels for the index before are: [18 10 14  0 18]
# The KNN categories are : ['talk.politics.misc' 'rec.sport.hockey' 'sci.space' 'alt.atheism'
#  'talk.politics.misc']
# The final label is: 18
# The index of the K nearest neighbours are: [ 753 7182 5393 6147  516]
# The labels for the index before are: [16  1 15 15 12]
# The KNN categories are : ['talk.politics.guns' 'comp.graphics' 'soc.religion.christian'
#  'soc.religion.christian' 'sci.electronics']
# The final label is: 15
# The index of the K nearest neighbours are: [2163 2235 5592 1532 2271]
# The labels for the index before are: [ 0  3 12  0 18]
# The KNN categories are : ['alt.atheism' 'comp.sys.ibm.pc.hardware' 'sci.electronics' 'alt.atheism'
#  'talk.politics.misc']
# The final label is: 0
# The index of the K nearest neighbours are: [6583 3297  125 2810 3786]
# The labels for the index before are: [ 0  0 13 13 10]
# The KNN categories are : ['alt.atheism' 'alt.atheism' 'sci.med' 'sci.med' 'rec.sport.hockey']
# The final label is: 0
# The index of the K nearest neighbours are: [2639 3162  838  173 3098]
# The labels for the index before are: [17  0  8  8  5]
# The KNN categories are : ['talk.politics.mideast' 'alt.atheism' 'rec.motorcycles' 'rec.motorcycles'
#  'comp.windows.x']
# The final label is: 8
# The index of the K nearest neighbours are: [ 201 1514 2522  216 4862]
# The labels for the index before are: [7 7 8 1 1]
# The KNN categories are : ['rec.autos' 'rec.autos' 'rec.motorcycles' 'comp.graphics' 'comp.graphics']
# The final label is: 7
# The index of the K nearest neighbours are: [7198 2620 2238 1062 5311]
# The labels for the index before are: [ 9 17  3 19 13]
# The KNN categories are : ['rec.sport.baseball' 'talk.politics.mideast' 'comp.sys.ibm.pc.hardware'
#  'talk.religion.misc' 'sci.med']
# The final label is: 9
# The index of the K nearest neighbours are: [5147 6959 6680 7052 3981]
# The labels for the index before are: [12 15 10  4  1]
# The KNN categories are : ['sci.electronics' 'soc.religion.christian' 'rec.sport.hockey'
#  'comp.sys.mac.hardware' 'comp.graphics']
# The final label is: 12
# Final Accuracy is: 0.7525
