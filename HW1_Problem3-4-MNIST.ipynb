# %% [markdown]
# # MNIST

# %%
# source: http://scikit-learn.org/stable/datasets/index.html

from sklearn.datasets import fetch_mldata
mnist = fetch_mldata('MNIST original')

print(mnist.data.shape)

# code source from http://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.euclidean_distances.html
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.metrics.pairwise import cosine_similarity

# to get part of the data set, otherwise the laptop get stuck immediately 
# reference tutorial http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(mnist.data, mnist.target, train_size =0.25, stratify = mnist.target )

similarity_ED = euclidean_distances(X_train)

similarity_COSINE = cosine_similarity(X_train)

print(similarity_ED.shape)

print(similarity_COSINE.shape)
# Out:
# (70000, 784)
# /Users/deshenghu/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# (17500, 17500)
# (17500, 17500)

# %%
import numpy as np

# learn code from this source: https://docs.python.org/2/library/collections.html#collections.Counter
# A Counter is a dict subclass for counting hashable objects. 
from collections import Counter

def Find_KNN(idx, k, similarity_matrix):
    index_KNN = np.argsort(np.array(similarity_ED[idx, :]))[:k]
    print("The index of the K nearest neighbours are:",index_KNN)
    
   
    label_final , count = Counter(Y_train[index_KNN]).most_common()[0]
    
    print("The labels for the index before are:",Y_train[index_KNN])
   # print(list(Y_train[index_KNN])
    print("The final label is:", label_final)
    
    
    return label_final

Find_KNN(10, 3, similarity_ED )
# Out:
# The index of the K nearest neighbours are: [   10 15242  9906]
# The labels for the index before are: [ 2.  2.  2.]
# The final label is: 2.0
# 2.0

# %%
seed_index = np.random.randint(17500, size=170)
print(seed_index)

count_accuracy = 0

for i in seed_index:
    train_label = Find_KNN(i, 3, similarity_ED)
    real_label = Y_train[i]
    if train_label== real_label:
        count_accuracy += 1
       
    #print(train_label, real_label)

Final_accuracy = float(count_accuracy)/float(len(seed_index))
print("Final Accuracy is:", Final_accuracy ) 
    
    #if train_label
# Out:
# [  451  9879 11146 ...,  2771 11783  3089]
# The index of the K nearest neighbours are: [  451 13051  3304]
# The labels for the index before are: [ 6.  6.  6.]
# The final label is: 6.0
# The index of the K nearest neighbours are: [9879 1488 4564]
# The labels for the index before are: [ 1.  1.  1.]
# The final label is: 1.0
# The index of the K nearest neighbours are: [11146 11439  4531]
# The labels for the index before are: [ 0.  0.  0.]
# The final label is: 0.0
# The index of the K nearest neighbours are: [4424 8194 6008]
# The labels for the index before are: [ 4.  4.  4.]
# The final label is: 4.0
# The index of the K nearest neighbours are: [6922 1440 4078]
# The labels for the index before are: [ 3.  3.  3.]
# The final label is: 3.0
# The index of the K nearest neighbours are: [16011 11775   130]
# The labels for the index before are: [ 9.  9.  9.]
# The final label is: 9.0
# The index of the K nearest neighbours are: [12588  1126 13676]
# The labels for the index before are: [ 8.  8.  9.]
# The final label is: 8.0
# The index of the K nearest neighbours are: [16769  2824   256]
# The labels for the index before are: [ 2.  2.  2.]
# The final label is: 2.0
# The index of the K nearest neighbours are: [12392 15931  3538]
# The labels for the index before are: [ 9.  9.  9.]
# The final label is: 9.0
# The index of the K nearest neighbours are: [ 3938 15443  3078]
# The labels for the index before are: [ 1.  1.  1.]
# The final label is: 1.0
# The index of the K nearest neighbours are: [1721 5688 3728]
# The labels for the index before are: [ 4.  4.  4.]
# The final label is: 4.0
# The index of the K nearest neighbours are: [ 1240 13739 14890]
# The labels for the index before are: [ 2.  2.  2.]
# The final label is: 2.0
# The index of the K nearest neighbours are: [ 3787 12647 11080]
# The labels for the index before are: [ 4.  4.  4.]
# The final label is: 4.0
# The index of the K nearest neighbours are: [13838  9562 15770]
# The labels for the index before are: [ 4.  4.  4.]
# The final label is: 4.0
# The index of the K nearest neighbours are: [15238  8410  6719]
# The labels for the index before are: [ 5.  5.  5.]
# The final label is: 5.0
# The index of the K nearest neighbours are: [ 4522 12132 16888]
# The labels for the index before are: [ 9.  9.  9.]
# The final label is: 9.0
# The index of the K nearest neighbours are: [ 7177  1316 16317]
# The labels for the index before are: [ 3.  3.  3.]
# The final label is: 3.0
# The index of the K nearest neighbours are: [10802    43 12530]
# The labels for the index before are: [ 5.  5.  5.]
# The final label is: 5.0
# The index of the K nearest neighbours are: [ 5770 14407  1990]
# The labels for the index before are: [ 8.  5.  5.]
# The final label is: 5.0
# The index of the K nearest neighbours are: [15142 14017 16184]
# The labels for the index before are: [ 3.  3.  3.]
# The final label is: 3.0
# The index of the K nearest neighbours are: [12175 10497   939]
# The labels for the index before are: [ 9.  9.  9.]
# The final label is: 9.0
# The index of the K nearest neighbours are: [ 8986  3244 12830]
# The labels for the index before are: [ 2.  2.  2.]
# The final label is: 2.0
# The index of the K nearest neighbours are: [15297 17310  7804]
# The labels for the index before are: [ 2.  2.  2.]
# The final label is: 2.0
# The index of the K nearest neighbours are: [1046 8096 4841]
# The labels for the index before are: [ 8.  8.  8.]
# The final label is: 8.0
# The index of the K nearest neighbours are: [ 3028 11051 13177]
# The labels for the index before are: [ 4.  4.  4.]
# The final label is: 4.0
# The index of the K nearest neighbours are: [ 6431 10239  9478]
# The labels for the index before are: [ 0.  0.  0.]
# The final label is: 0.0
# The index of the K nearest neighbours are: [13558 11966 13283]
# The labels for the index before are: [ 1.  1.  1.]
# The final label is: 1.0
# The index of the K nearest neighbours are: [13442   191 14657]
# The labels for the index before are: [ 1.  1.  1.]
# The final label is: 1.0
# The index of the K nearest neighbours are: [ 7402  9527 15718]
# The labels for the index before are: [ 7.  7.  7.]
# The final label is: 7.0
# The index of the K nearest neighbours are: [10089 12708  5799]
# The labels for the index before are: [ 9.  9.  7.]
# The final label is: 9.0
# The index of the K nearest neighbours are: [11052 13524  5786]
# The labels for the index before are: [ 6.  6.  6.]
# The final label is: 6.0
# The index of the K nearest neighbours are: [  982 12131 10674]
# The labels for the index before are: [ 3.  3.  3.]
# The final label is: 3.0
# The index of the K nearest neighbours are: [14710 11316  2595]
# The labels for the index before are: [ 6.  6.  6.]
# The final label is: 6.0
# The index of the K nearest neighbours are: [2953 7908 4072]
# The labels for the index before are: [ 5.  5.  5.]
# The final label is: 5.0
# The index of the K nearest neighbours are: [14453 13190 11689]
# The labels for the index before are: [ 9.  9.  9.]
# The final label is: 9.0
# The index of the K nearest neighbours are: [ 3044 15824 13571]
# The labels for the index before are: [ 7.  7.  7.]
# The final label is: 7.0
# The index of the K nearest neighbours are: [4919 4188 8360]
# The labels for the index before are: [ 0.  0.  0.]
# The final label is: 0.0
# The index of the K nearest neighbours are: [ 8542 12824 11519]
# The labels for the index before are: [ 0.  0.  0.]
# The final label is: 0.0
# The index of the K nearest neighbours are: [15427  1530  6230]
# The labels for the index before are: [ 3.  3.  3.]
# The final label is: 3.0
# The index of the K nearest neighbours are: [ 6180 13590 17328]
# The labels for the index before are: [ 4.  4.  4.]
# The final label is: 4.0
# The index of the K nearest neighbours are: [2018 6349 8079]
# The labels for the index before are: [ 4.  4.  4.]
# The final label is: 4.0
# The index of the K nearest neighbours are: [ 5841 15269  5974]
# The labels for the index before are: [ 0.  0.  0.]
# The final label is: 0.0
# The index of the K nearest neighbours are: [16300  5010  9957]
# The labels for the index before are: [ 4.  4.  4.]
# The final label is: 4.0
# The index of the K nearest neighbours are: [    5 12091 14304]
# The labels for the index before are: [ 1.  1.  1.]
# The final label is: 1.0
# The index of the K nearest neighbours are: [11614 16766  6594]
# The labels for the index before are: [ 5.  5.  5.]
# The final label is: 5.0
# The index of the K nearest neighbours are: [ 4420 11955  8699]
# The labels for the index before are: [ 2.  2.  2.]
# The final label is: 2.0
# The index of the K nearest neighbours are: [11449  9904  8739]
# The labels for the index before are: [ 6.  6.  6.]
# The final label is: 6.0
# The index of the K nearest neighbours are: [   75  8704 14382]
# The labels for the index before are: [ 7.  7.  7.]
# The final label is: 7.0
# The index of the K nearest neighbours are: [11163  6456 15652]
# The labels for the index before are: [ 1.  1.  1.]
# The final label is: 1.0
# The index of the K nearest neighbours are:

# The labels for the index before are: [ 4.  4.  4.]
# The final label is: 4.0
# The index of the K nearest neighbours are: [13562  1608 11937]
# The labels for the index before are: [ 0.  0.  0.]
# The final label is: 0.0
# The index of the K nearest neighbours are: [  833 15788  1302]
# The labels for the index before are: [ 6.  6.  6.]
# The final label is: 6.0
# The index of the K nearest neighbours are: [13542  7136 14155]
# The labels for the index before are: [ 6.  6.  6.]
# The final label is: 6.0
# The index of the K nearest neighbours are: [12654 14964  1688]
# The labels for the index before are: [ 0.  0.  0.]
# The final label is: 0.0
# The index of the K nearest neighbours are: [ 9798  6734 11398]
# The labels for the index before are: [ 1.  1.  1.]
# The final label is: 1.0
# The index of the K nearest neighbours are: [14329 16004  3937]
# The labels for the index before are: [ 6.  6.  6.]
# The final label is: 6.0
# The index of the K nearest neighbours are: [6674  734 4614]
# The labels for the index before are: [ 8.  8.  8.]
# The final label is: 8.0
# The index of the K nearest neighbours are: [10223 12151  1934]
# The labels for the index before are: [ 7.  7.  7.]
# The final label is: 7.0
# The index of the K nearest neighbours are: [16103  9488  5302]
# The labels for the index before are: [ 1.  1.  1.]
# The final label is: 1.0
# The index of the K nearest neighbours are: [ 1319 14220 16816]
# The labels for the index before are: [ 2.  2.  2.]
# The final label is: 2.0
# The index of the K nearest neighbours are: [13826   142  7396]
# The labels for the index before are: [ 3.  3.  3.]
# The final label is: 3.0
# The index of the K nearest neighbours are: [ 6165 10536  6245]
# The labels for the index before are: [ 0.  0.  0.]
# The final label is: 0.0
# The index of the K nearest neighbours are: [13237  4067 17467]
# The labels for the index before are: [ 5.  5.  5.]
# The final label is: 5.0
# The index of the K nearest neighbours are: [1385 4486 3776]
# The labels for the index before are: [ 5.  5.  5.]
# The final label is: 5.0
# The index of the K nearest neighbours are: [10618  2614  6854]
# The labels for the index before are: [ 6.  6.  6.]
# The final label is: 6.0
# The index of the K nearest neighbours are: [  462 15227 11639]
# The labels for the index before are: [ 8.  8.  8.]
# The final label is: 8.0
# The index of the K nearest neighbours are: [ 3927 14632  3259]
# The labels for the index before are: [ 9.  9.  9.]
# The final label is: 9.0
# The index of the K nearest neighbours are: [11686 10902  8647]
# The labels for the index before are: [ 4.  9.  4.]
# The final label is: 4.0
# The index of the K nearest neighbours are: [ 8183 10264  9401]
# The labels for the index before are: [ 0.  0.  6.]
# The final label is: 0.0
# The index of the K nearest neighbours are: [5868 9726 4642]
# The labels for the index before are: [ 2.  2.  2.]
# The final label is: 2.0
# The index of the K nearest neighbours are: [ 2216 12177 13363]
# The labels for the index before are: [ 5.  5.  9.]
# The final label is: 5.0
# The index of the K nearest neighbours are: [1681 1888 9633]
# The labels for the index before are: [ 6.  6.  6.]
# The final label is: 6.0
# The index of the K nearest neighbours are: [11725 11340 12945]
# The labels for the index before are: [ 7.  7.  7.]
# The final label is: 7.0
# The index of the K nearest neighbours are: [3114 6570 9004]
# The labels for the index before are: [ 3.  3.  3.]
# The final label is: 3.0
# The index of the K nearest neighbours are: [ 7014 15364  1520]
# The labels for the index before are: [ 7.  7.  7.]
# The final label is: 7.0
# The index of the K nearest neighbours are: [ 2100   786 10485]
# The labels for the index before are: [ 2.  2.  2.]
# The final label is: 2.0
# The index of the K nearest neighbours are: [ 7569 11057  1730]
# The labels for the index before are: [ 7.  7.  7.]
# The final label is: 7.0
# The index of the K nearest neighbours are: [ 1891  7003 11098]
# The labels for the index before are: [ 8.  8.  8.]
# The final label is: 8.0
# The index of the K nearest neighbours are: [ 4716  7472 15015]
# The labels for the index before are: [ 7.  7.  7.]
# The final label is: 7.0
# The index of the K nearest neighbours are: [ 4552 14536  5744]
# The labels for the index before are: [ 8.  8.  8.]
# The final label is: 8.0
# The index of the K nearest neighbours are: [ 8243 10877  8499]
# The labels for the index before are: [ 3.  3.  3.]
# The final label is: 3.0
# The index of the K nearest neighbours are: [17452  9878  8374]
# The labels for the index before are: [ 5.  5.  5.]
# The final label is: 5.0
# The index of the K nearest neighbours are: [11864 15980 12432]
# The labels for the index before are: [ 7.  7.  7.]
# The final label is: 7.0
# The index of the K nearest neighbours are: [ 9506  2637 13987]
# The labels for the index before are: [ 3.  3.  3.]
# The final label is: 3.0
# The index of the K nearest neighbours are: [ 9171  4168 12103]
# The labels for the index before are: [ 3.  3.  3.]
# The final label is: 3.0
# The index of the K nearest neighbours are: [ 5171  7267 12447]
# The labels for the index before are: [ 1.  1.  1.]
# The final label is: 1.0
# The index of the K nearest neighbours are: [15422 11300 13867]
# The labels for the index before are: [ 6.  6.  6.]
# The final label is: 6.0
# The index of the K nearest neighbours are: [10644  1931  6435]
# The labels for the index before are: [ 8.  8.  8.]
# The final label is: 8.0
# The index of the K nearest neighbours are: [13682  7719  5331]
# The labels for the index before are: [ 7.  7.  7.]
# The final label is: 7.0
# The index of the K nearest neighbours are: [11540 15269  7132]
# The labels for the index before are: [ 0.  0.  0.]
# The final label is: 0.0
# The index of the K nearest neighbours are: [6002  419  385]
# The labels for the index before are: [ 3.  3.  3.]
# The final label is: 3.0
# The index of the K nearest neighbours are: [ 5675 14960  6457]
# The labels for the index before are: [ 0.  0.  0.]
# The final label is: 0.0
# The index of the K nearest neighbours are: [13426 15747  5973]
# The labels for the index before are: [ 2.  2.  2.]
# The final label is: 2.0
# The index of the K nearest neighbours are: [17016 17317  5735]
# The labels for the index before are: [ 1.  1.  1.]
# The final label is: 1.0
# The index of the K nearest neighbours are: [4392 3733 5134]
# The labels for the index before are: [ 1.  1.  1.]
# The final label is: 1.0
# The index of the K nearest neighbours are: [9604 1377 5088]
# The labels for the index before are: [ 0.  0.  0.]
# The final label is: 0.0
# The index of the K nearest neighbours are: [17022  4344 12058]
# The labels for the index before are: [ 8.  8.  8.]
# The final label is: 8.0
# The index of the K nearest neighbours are: [ 3592  7760 14301]
# The labels for the index before are: [ 8.  3.  8.]
# The final label is: 8.0
# The index of the K nearest neighbours are: [ 6324  6473 11154]
# The labels for the index before are: [ 4.  4.  4.]
# The final label is: 4.0
# The index of the K nearest neighbours are: [13490 15086  6028]
# The labels for the index before are: [ 0.  0.  0.]
# The final label is: 0.0
# The index of the K nearest neighbours are: [8733  158  650]
# The labels for the index before are: [ 8.  8.  8.]
# The final label is: 8.0
# The index of the K nearest neighbours are: [13748 13750 14642]
# The labels for the index before are: [ 5.  5.  5.]
# The final label is: 5.0
# The index of the K nearest neighbours are: [ 9924  1830 13245]
# The labels for the index before are: [ 2.  2.  6.]
# The final label is: 2.0
# The index of the K nearest neighbours are: [16480  9997  9201]
# The labels for the index before are: [ 6.  6.  6.]
# The final label is: 6.0
# The index of the K nearest neighbours are: [12146 14111 15267]
# The labels for the index before are: [ 7.  7.  7.]
# The final label is: 7.0
# The index of the K nearest neighbours are: [2614 8353 8018]
# The labels for the index before are: [ 6.  6.  6.]
# The final label is: 6.0
# The index of the K nearest neighbours are: [6318 2616 3199]
# The labels for the index before are: [ 2.  2.  2.]
# The final label is: 2.0
# The index of the K nearest neighbours are: [ 8757 11863 12947]
# The labels for the index before are: [ 7.  7.  7.]
# The final label is: 7.0
# The index of the K nearest neighbours are: [17444   969 15187]
# The labels for the index before are: [ 3.  3.  3.]
# The final label is: 3.0
# The index of the K nearest neighbours are: [16085  3075 12521]
# The labels for the index before are: [ 7.  7.  7.]
# The final label is: 7.0
# The index of the K nearest neighbours are: [17079  1158 13520]
# The labels for the index before are: [ 4.  4.  4.]
# The final label is: 4.0
# The index of the K nearest neighbours are: [16203   202 16603]
# The labels for the index before are: [ 3.  3.  3.]
# The final label is: 3.0
# The index of the K nearest neighbours are: [16391 11537  1471]
# The labels for the index before are: [ 6.  6.  6.]
# The final label is: 6.0
# The index of the K nearest neighbours are: [ 1045 12860 16092]
# The labels for the index before are: [ 3.  3.  3.]
# The final label is: 3.0
# The index of the K nearest neighbours are: [ 1423 10012 14837]
# The labels for the index before are: [ 3.  3.  3.]
# The final label is: 3.0
# The index of the K nearest neighbours are: [ 3942 17085 17154]
# The labels for the index before are: [ 3.  8.  3.]
# The final label is: 3.0
# The index of the K nearest neighbours are: [ 8384 16909 10630]
# The labels for the index before are: [ 5.  5.  5.]
# The final label is: 5.0
# The index of the K nearest neighbours are: [ 2771 10232  8614]
# The labels for the index before are: [ 1.  1.  1.]
# The final label is: 1.0
# The index of the K nearest neighbours are: [11783  8250  1943]
# The labels for the index before are: [ 8.  8.  8.]
# The final label is: 8.0
# The index of the K nearest neighbours are: [3089 3717 4465]
# The labels for the index before are: [ 8.  8.  8.]
# The final label is: 8.0
# Final Accuracy is: 0.9770588235294118
